# %%
#Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from citipy import citipy

# %%
#Create a new set of 2,000 random latitudes and longitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
coordinates = list(lat_lngs)

cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

#print city count
len(cities)
# Out:
# 761

# %%
# Starting URL for Weather Map API Call.
import requests
from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#Create list to hold weather data
city_data = []

#Print beginning log
print("..............Beginning Data Retrieval............")

#Create counters
record_count = 1
set_count = 1

#Loop through cities in list
for i, city in enumerate(cities):
    
    #Group cities in sets of 50 for log
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    #create end point URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    #Log URL, record, set numbers and city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    #add 1 to record count
    record_count += 1
   
    #run an api request for each city
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
    
    #If error is received, skip the city.
    except:
        print("........City not found. Skipping.......")
        pass

#Indicate data loading is complete
print("..............Data Retrieval Complete...........")
# Out:
# ..............Beginning Data Retrieval............
# Processing Record 1 of Set 1 | tasiilaq
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | avarua
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | san jose
# Processing Record 6 of Set 1 | ancud
# Processing Record 7 of Set 1 | boddam
# Processing Record 8 of Set 1 | lazurne
# Processing Record 9 of Set 1 | thompson
# Processing Record 10 of Set 1 | mataura
# Processing Record 11 of Set 1 | jamestown
# Processing Record 12 of Set 1 | mys shmidta
# ........City not found. Skipping.......
# Processing Record 13 of Set 1 | albany
# Processing Record 14 of Set 1 | ugoofaaru
# Processing Record 15 of Set 1 | atuona
# Processing Record 16 of Set 1 | souillac
# Processing Record 17 of Set 1 | northam
# Processing Record 18 of Set 1 | san carlos
# Processing Record 19 of Set 1 | zhigansk
# Processing Record 20 of Set 1 | chokurdakh
# Processing Record 21 of Set 1 | gillette
# Processing Record 22 of Set 1 | busselton
# Processing Record 23 of Set 1 | novaya lyalya
# Processing Record 24 of Set 1 | pevek
# Processing Record 25 of Set 1 | yellowknife
# Processing Record 26 of Set 1 | tiksi
# Processing Record 27 of Set 1 | khatanga
# Processing Record 28 of Set 1 | grand river south east
# ........City not found. Skipping.......
# Processing Record 29 of Set 1 | sebrovo
# Processing Record 30 of Set 1 | bengkulu
# Processing Record 31 of Set 1 | shahr-e babak
# Processing Record 32 of Set 1 | asfi
# Processing Record 33 of Set 1 | vao
# Processing Record 34 of Set 1 | illoqqortoormiut
# ........City not found. Skipping.......
# Processing Record 35 of Set 1 | hithadhoo
# Processing Record 36 of Set 1 | hermanus
# Processing Record 37 of Set 1 | vaini
# Processing Record 38 of Set 1 | alekseyevka
# Processing Record 39 of Set 1 | puerto escondido
# Processing Record 40 of Set 1 | puri
# Processing Record 41 of Set 1 | mount gambier
# Processing Record 42 of Set 1 | norman wells
# Processing Record 43 of Set 1 | bredasdorp
# Processing Record 44 of Set 1 | kruisfontein
# Processing Record 45 of Set 1 | dikson
# Processing Record 46 of Set 1 | brae
# Processing Record 47 of Set 1 | srednekolymsk
# Processing Record 48 of Set 1 | cape town
# Processing Record 49 of Set 1 | faanui
# Processing Record 50 of Set 1 | taolanaro
# ........City not found. Skipping.......
# Processing Record 1 of Set 2 | tiarei
# Processing Record 2 of Set 2 | nioro
# Processing Record 3 of Set 2 | tunduru
# ........City not found. Skipping.......
# Processing Record 4 of Set 2 | barrow
# Processing Record 5 of Set 2 | rio verde de mato grosso
# Processing Record 6 of Set 2 | copiapo
# Processing Record 7 of Set 2 | clyde river
# Processing Record 8 of Set 2 | solnechnyy
# Processing Record 9 of Set 2 | necochea
# Processing Record 10 of Set 2 | qaanaaq
# Processing Record 11 of Set 2 | adrar
# Processing Record 12 of Set 2 | lebu
# Processing Record 13 of Set 2 | ixtapa
# Processing Record 14 of Set 2 | arraial do cabo
# Processing Record 15 of Set 2 | nabire
# Processing Record 16 of Set 2 | sorland
# Processing Record 17 of Set 2 | formoso do araguaia
# ........City not found. Skipping.......
# Processing Record 18 of Set 2 | el cobre
# Processing Record 19 of Set 2 | baykit
# Processing Record 20 of Set 2 | new norfolk
# Processing Record 21 of Set 2 | paita
# Processing Record 22 of Set 2 | iqaluit
# Processing Record 23 of Set 2 | constitucion
# Processing Record 24 of Set 2 | kirakira
# Processing Record 25 of Set 2 | port alfred
# Processing Record 26 of Set 2 | hilo
# Processing Record 27 of Set 2 | victoria
# Processing Record 28 of Set 2 | severo-kurilsk
# Processing Record 29 of Set 2 | zhangye
# Processing Record 30 of Set 2 | namibe
# Processing Record 31 of Set 2 | chanasma
# Processing Record 32 of Set 2 | lalitpur
# Processing Record 33 of Set 2 | punta arenas
# Processing Record 34 of Set 2 | cururupu
# Processing Record 35 of Set 2 | meridian
# Processing Record 36 of Set 2 | alamogordo
# Processing Record 37 of Set 2 | kyren
# Processing Record 38 of Set 2 | pasighat
# Processing Record 39 of Set 2 | seydi
# Processing Record 40 of Set 2 | longlac
# ........City not found. Skipping.......
# Processing Record 41 of Set 2 | oranjemund
# ........City not found. Skipping.......
# Processing Record 42 of Set 2 | haines junction
# Processing Record 43 of Set 2 | kamenka
# Processing Record 44 of Set 2 | golden
# Processing Record 45 of Set 2 | ucluelet
# Processing Record 46 of Set 2 | kaitangata
# Processing Record 47 of Set 2 | mar del plata
# Processing Record 48 of Set 2 | abha
# Processing Record 49 of Set 2 | enshi
# Processing Record 50 of Set 2 | ayagoz
# Processing Record 1 of Set 3 | winslow
# Processing Record 2 of Set 3 | cordoba
# Processing Record 3 of Set 3 | wanning
# Processing Record 4 of Set 3 | awbari
# Processing Record 5 of Set 3 | kodiak
# Processing Record 6 of Set 3 | urumqi
# Processing Record 7 of Set 3 | poum
# Processing Record 8 of Set 3 | faya
# Processing Record 9 of Set 3 | masuguru
# Processing Record 10 of Set 3 | santa rosa
# Processing Record 11 of Set 3 | east london
# Processing Record 12 of Set 3 | montepuez
# Processing Record 13 of Set 3 | westpunt
# ........City not found. Skipping.......
# Processing Record 14 of Set 3 | broome
# Processing Record 15 of Set 3 | micheweni
# Processing Record 16 of Set 3 | solenzo
# Processing Record 17 of Set 3 | upernavik
# Processing Record 18 of Set 3 | kavaratti
# Processing Record 19 of Set 3 | lata
# Processing Record 20 of Set 3 | kapaa
# Processing Record 21 of Set 3 | lafiagi
# Processing Record 22 of Set 3 | saint-philippe
# Processing Record 23 of Set 3 | tuatapere
# Processing Record 24 of Set 3 | dingle
# Processing Record 25 of Set 3 | pacific grove
# Processing Record 26 of Set 3 | marathon
# ........City not found. Skipping.......
# Processing Record 27 of Set 3 | ust-nera
# Processing Record 28 of Set 3 | santa cruz
# Processing Record 29 of Set 3 | port elizabeth
# Processing Record 30 of Set 3 | vaitupu
# ........City not found. Skipping.......
# Processing Record 31 of Set 3 | bambous virieux
# Processing Record 32 of Set 3 | akcaabat
# Processing Record 33 of Set 3 | bluff
# Processing Record 34 of Set 3 | provideniya
# Processing Record 35 of Set 3 | hervey bay
# Processing Record 36 of Set 3 | beyneu
# Processing Record 37 of Set 3 | pantai remis
# Processing Record 38 of Set 3 | zhuhai
# Processing Record 39 of Set 3 | saskylakh
# Processing Record 40 of Set 3 | jiuquan
# Processing Record 41 of Set 3 | kuppam
# Processing Record 42 of Set 3 | malakal
# Processing Record 43 of Set 3 | nikolskoye
# Processing Record 44 of Set 3 | bettiah
# Processing Record 45 of Set 3 | cabo san lucas
# Processing Record 46 of Set 3 | manggar
# Processing Record 47 of Set 3 | puerto ayora
# Processing Record 48 of Set 3 | havre-saint-pierre
# Processing Record 49 of Set 3 | ahipara
# Processing Record 50 of Set 3 | mount isa
# Processing Record 1 of Set 4 | chota
# Processing Record 2 of Set 4 | isangel
# Processing Record 3 of Set 4 | talnakh
# Processing Record 4 of Set 4 | ilulissat
# Processing Record 5 of Set 4 | krasnoarmeysk
# Processing Record 6 of Set 4 | guadalajara
# Processing Record 7 of Set 4 | naryan-mar
# Processing Record 8 of Set 4 | klaksvik
# Processing Record 9 of Set 4 | vila franca do campo
# Processing Record 10 of Set 4 | cidreira
# Processing Record 11 of Set 4 | amahai
# Processing Record 12 of Set 4 | nizhneyansk
# ........City not found. Skipping.......
# Processing Record 13 of Set 4 | avera
# Processing Record 14 of Set 4 | elat
# Processing Record 15 of Set 4 | umzimvubu
# ........City not found. Skipping.......
# Processing Record 16 of Set 4 | freital
# Processing Record 17 of Set 4 | buin
# Processing Record 18 of Set 4 | caravelas
# Processing Record 19 of Set 4 | kedrovyy
# Processing Record 20 of Set 4 | bethanien
# Processing Record 21 of Set 4 | pierre
# Processing Record 22 of Set 4 | dundee
# Processing Record 23 of Set 4 | midyat
# Processing Record 24 of Set 4 | palmer
# Processing Record 25 of Set 4 | adeje
# Processing Record 26 of Set 4 | maloshuyka
# ........City not found. Skipping.......
# Processing Record 27 of Set 4 | robertsport
# Processing Record 28 of Set 4 | asarganj
# Processing Record 29 of Set 4 | esperance
# Processing Record 30 of Set 4 | harigue
# ........City not found. Skipping.......
# Processing Record 31 of Set 4 | carnarvon
# Processing Record 32 of Set 4 | belmonte
# Processing Record 33 of Set 4 | aksarka
# Processing Record 34 of Set 4 | fukue
# Processing Record 35 of Set 4 | cayenne
# Processing Record 36 of Set 4 | pleasantville
# Processing Record 37 of Set 4 | gazli
# Processing Record 38 of Set 4 | aykhal
# Processing Record 39 of Set 4 | araouane
# Processing Record 40 of Set 4 | husavik
# Processing Record 41 of Set 4 | belem de sao francisco
# Processing Record 42 of Set 4 | paamiut
# Processing Record 43 of Set 4 | mayor pablo lagerenza
# Processing Record 44 of Set 4 | omsukchan
# Processing Record 45 of Set 4 | lokossa
# Processing Record 46 of Set 4 | borlange
# ........City not found. Skipping.......
# Processing Record 47 of Set 4 | hillsborough
# Processing Record 48 of Set 4 | katangli
# Processing Record 49 of Set 4 | ondorhaan
# ........City not found. Skipping.......
# Processing Record 50 of Set 4 | butaritari
# Processing Record 1 of Set 5 | seguela
# Processing Record 2 of Set 5 | gainesville
# Processing Record 3 of Set 5 | okha
# Processing Record 4 of Set 5 | lorengau
# Processing Record 5 of Set 5 | amderma
# ........City not found. Skipping.......
# Processing Record 6 of Set 5 | paracatu
# Processing Record 7 of Set 5 | pisco
# Processing Record 8 of Set 5 | ust-kamchatsk
# ........City not found. Skipping.......
# Processing Record 9 of Set 5 | voh
# Processing Record 10 of Set 5 | puerto penasco
# Processing Record 11 of Set 5 | ketchikan
# Processing Record 12 of Set 5 | karlshamn
# Processing Record 13 of Set 5 | saint-pierre
# Processing Record 14 of Set 5 | borogontsy
# Processing Record 15 of Set 5 | kingaroy
# Processing Record 16 of Set 5 | sam phran
# Processing Record 17 of Set 5 | vostok
# Processing Record 18 of Set 5 | sioux lookout
# Processing Record 19 of Set 5 | guerrero negro
# Processing Record 20 of Set 5 | namatanai
# Processing Record 21 of Set 5 | cabra
# Processing Record 22 of Set 5 | huzhou
# Processing Record 23 of Set 5 | krasnoselkup
# Processing Record 24 of Set 5 | hobart
# Processing Record 25 of Set 5 | harbin
# Processing Record 26 of Set 5 | thunder bay
# Processing Record 27 of Set 5 | coihaique
# Processing Record 28 of Set 5 | ponta do sol
# Processing Record 29 of Set 5 | barentsburg
# ........City not found. Skipping.......
# Processing Record 30 of Set 5 | inongo
# Processing Record 31 of Set 5 | lokosovo
# Processing Record 32 of Set 5 | louisbourg
# ........City not found. Skipping.......
# Processing Record 33 of Set 5 | north bend
# Processing Record 34 of Set 5 | robore
# Processing Record 35 of Set 5 | chagda
# ........City not found. Skipping.......
# Processing Record 36 of Set 5 | litoral del san juan
# ........City not found. Skipping.......
# Processing Record 37 of Set 5 | secunda
# Processing Record 38 of Set 5 | abashiri
# Processing Record 39 of Set 5 | marcona
# ........City not found. Skipping.......
# Processing Record 40 of Set 5 | loharu
# Processing Record 41 of Set 5 | kushima
# Processing Record 42 of Set 5 | grindavik
# Processing Record 43 of Set 5 | inirida
# Processing Record 44 of Set 5 | ukiah
# Processing Record 45 of Set 5 | torbay
# Processing Record 46 of Set 5 | campos gerais
# Processing Record 47 of Set 5 | priiskovyy
# Processing Record 48 of Set 5 | port blair
# Processing Record 49 of Set 5 | berlevag
# Processing Record 50 of Set 5 | tartagal
# Processing Record 1 of Set 6 | neiafu
# Processing Record 2 of Set 6 | harper
# Processing Record 3 of Set 6 | cockburn town
# Processing Record 4 of Set 6 | puerto baquerizo moreno
# Processing Record 5 of Set 6 | camana
# Processing Record 6 of Set 6 | umm lajj
# Processing Record 7 of Set 6 | phumi samraong
# ........City not found. Skipping.......
# Processing Record 8 of Set 6 | agbor
# Processing Record 9 of Set 6 | sibolga
# Processing Record 10 of Set 6 | mitsamiouli
# Processing Record 11 of Set 6 | bathsheba
# Processing Record 12 of Set 6 | tuktoyaktuk
# Processing Record 13 of Set 6 | humaita
# Processing Record 14 of Set 6 | santiago del estero
# Processing Record 15 of Set 6 | portland
# Processing Record 16 of Set 6 | kulu
# Processing Record 17 of Set 6 | fortuna
# Processing Record 18 of Set 6 | chanute
# Processing Record 19 of Set 6 | la ronge
# Processing Record 20 of Set 6 | whitehorse
# Processing Record 21 of Set 6 | lubsko
# Processing Record 22 of Set 6 | beausejour
# Processing Record 23 of Set 6 | fort walton beach
# Processing Record 24 of Set 6 | vityazevo
# Processing Record 25 of Set 6 | atambua
# Processing Record 26 of Set 6 | sentyabrskiy
# ........City not found. Skipping.......
# Processing Record 27 of Set 6 | madison
# Processing Record 28 of Set 6 | labuhan
# Processing Record 29 of Set 6 | changuinola
# Processing Record 30 of Set 6 | qingdao
# Processing Record 31 of Set 6 | tabukiniberu
# ........City not found. Skipping.......
# Processing Record 32 of Set 6 | gaoua
# Processing Record 33 of Set 6 | rawson
# Processing Record 34 of Set 6 | oktyabrskoye
# Processing Record 35 of Set 6 | sechura
# Processing Record 36 of Set 6 | schonebeck
# Processing Record 37 of Set 6 | grand-lahou
# Processing Record 38 of Set 6 | fare
# Processing Record 39 of Set 6 | koutiala
# Processing Record 40 of Set 6 | kapit
# Processing Record 41 of Set 6 | cherskiy
# Processing Record 42 of Set 6 | teguise
# Processing Record 43 of Set 6 | muli
# Processing Record 44 of Set 6 | khani
# Processing Record 45 of Set 6 | tutoia
# Processing Record 46 of Set 6 | ribeira grande
# Processing Record 47 of Set 6 | kulhudhuffushi
# Processing Record 48 of Set 6 | tura
# Processing Record 49 of Set 6 | impfondo
# Processing Record 50 of Set 6 | burns lake
# Processing Record 1 of Set 7 | roald
# Processing Record 2 of Set 7 | alugan
# Processing Record 3 of Set 7 | nakapiripirit
# Processing Record 4 of Set 7 | coquimbo
# Processing Record 5 of Set 7 | port hedland
# Processing Record 6 of Set 7 | kumano
# Processing Record 7 of Set 7 | asyut
# Processing Record 8 of Set 7 | zyryanka
# Processing Record 9 of Set 7 | tezu
# Processing Record 10 of Set 7 | tsihombe
# ........City not found. Skipping.......
# Processing Record 11 of Set 7 | olafsvik
# Processing Record 12 of Set 7 | turukhansk
# Processing Record 13 of Set 7 | belushya guba
# ........City not found. Skipping.......
# Processing Record 14 of Set 7 | yanan
# ........City not found. Skipping.......
# Processing Record 15 of Set 7 | nome
# Processing Record 16 of Set 7 | airai
# Processing Record 17 of Set 7 | am timan
# Processing Record 18 of Set 7 | georgetown
# Processing Record 19 of Set 7 | bayangol
# Processing Record 20 of Set 7 | wairoa
# Processing Record 21 of Set 7 | scarborough
# Processing Record 22 of Set 7 | bethel
# Processing Record 23 of Set 7 | petropavlovskaya
# Processing Record 24 of Set 7 | shimoda
# Processing Record 25 of Set 7 | tete
# Processing Record 26 of Set 7 | skibbereen
# Processing Record 27 of Set 7 | vasilkovo
# ........City not found. Skipping.......
# Processing Record 28 of Set 7 | longyearbyen
# Processing Record 29 of Set 7 | marzuq
# Processing Record 30 of Set 7 | heiligenhafen
# Processing Record 31 of Set 7 | san carlos de bariloche
# Processing Record 32 of Set 7 | mudyuga
# ........City not found. Skipping.......
# Processing Record 33 of Set 7 | meulaboh
# Processing Record 34 of Set 7 | tiznit
# Processing Record 35 of Set 7 | codrington
# Processing Record 36 of Set 7 | cedar city
# Processing Record 37 of Set 7 | pangody
# Processing Record 38 of Set 7 | palabuhanratu
# ........City not found. Skipping.......
# Processing Record 39 of Set 7 | burica
# ........City not found. Skipping.......
# Processing Record 40 of Set 7 | rabo de peixe
# Processing Record 41 of Set 7 | chuy
# Processing Record 42 of Set 7 | alice springs
# Processing Record 43 of Set 7 | sao filipe
# Processing Record 44 of Set 7 | tazmalt
# Processing Record 45 of Set 7 | buenavista
# Processing Record 46 of Set 7 | bijar
# Processing Record 47 of Set 7 | margate
# Processing Record 48 of Set 7 | egvekinot
# Processing Record 49 of Set 7 | ichihara
# Processing Record 50 of Set 7 | nadvoitsy
# Processing Record 1 of Set 8 | katsuura
# Processing Record 2 of Set 8 | poshekhonye
# Processing Record 3 of Set 8 | ust-uda
# Processing Record 4 of Set 8 | imbituba
# Processing Record 5 of Set 8 | daru
# Processing Record 6 of Set 8 | panguna
# Processing Record 7 of Set 8 | sao joao da barra
# Processing Record 8 of Set 8 | kutahya
# Processing Record 9 of Set 8 | leningradskiy
# Processing Record 10 of Set 8 | tautira
# Processing Record 11 of Set 8 | pontianak
# Processing Record 12 of Set 8 | cairo
# Processing Record 13 of Set 8 | ruatoria
# ........City not found. Skipping.......
# Processing Record 14 of Set 8 | hay river
# Processing Record 15 of Set 8 | plover
# Processing Record 16 of Set 8 | kahului
# Processing Record 17 of Set 8 | kayiry
# Processing Record 18 of Set 8 | mtimbira
# Processing Record 19 of Set 8 | port-gentil
# Processing Record 20 of Set 8 | lagoa
# Processing Record 21 of Set 8 | anadyr
# Processing Record 22 of Set 8 | oussouye
# Processing Record 23 of Set 8 | strelka
# Processing Record 24 of Set 8 | yanam
# Processing Record 25 of Set 8 | zaysan
# Processing Record 26 of Set 8 | salym
# Processing Record 27 of Set 8 | malpe
# Processing Record 28 of Set 8 | seymchan
# Processing Record 29 of Set 8 | mae sot
# Processing Record 30 of Set 8 | mahebourg
# Processing Record 31 of Set 8 | lusambo
# Processing Record 32 of Set 8 | tabiauea
# ........City not found. Skipping.......
# Processing Record 33 of Set 8 | shingu
# Processing Record 34 of Set 8 | saint george
# Processing Record 35 of Set 8 | porto novo
# Processing Record 36 of Set 8 | coos bay
# Processing Record 37 of Set 8 | arinos
# Processing Record 38 of Set 8 | yagodnoye
# Processing Record 39 of Set 8 | san patricio
# Processing Record 40 of Set 8 | lake worth
# Processing Record 41 of Set 8 | salalah
# Processing Record 42 of Set 8 | fairbanks
# Processing Record 43 of Set 8 | ayorou
# Processing Record 44 of Set 8 | verkhnevilyuysk
# Processing Record 45 of Set 8 | playas
# Processing Record 46 of Set 8 | mandalgovi
# Processing Record 47 of Set 8 | san-pedro
# Processing Record 48 of Set 8 | mayo
# Processing Record 49 of Set 8 | sulangan
# Processing Record 50 of Set 8 | hammond
# Processing Record 1 of Set 9 | kudahuvadhoo
# Processing Record 2 of Set 9 | rongcheng
# Processing Record 3 of Set 9 | barbar
# ........City not found. Skipping.......
# Processing Record 4 of Set 9 | durusu
# Processing Record 5 of Set 9 | hofn
# Processing Record 6 of Set 9 | the valley
# Processing Record 7 of Set 9 | sorvag
# ........City not found. Skipping.......
# Processing Record 8 of Set 9 | aasiaat
# Processing Record 9 of Set 9 | saint-georges
# Processing Record 10 of Set 9 | inhambane
# Processing Record 11 of Set 9 | mocambique
# ........City not found. Skipping.......
# Processing Record 12 of Set 9 | samusu
# ........City not found. Skipping.......
# Processing Record 13 of Set 9 | nara
# Processing Record 14 of Set 9 | ariquemes
# Processing Record 15 of Set 9 | general roca
# Processing Record 16 of Set 9 | opuwo
# Processing Record 17 of Set 9 | makambako
# Processing Record 18 of Set 9 | bantry
# Processing Record 19 of Set 9 | vestmannaeyjar
# Processing Record 20 of Set 9 | moshny
# Processing Record 21 of Set 9 | sitka
# Processing Record 22 of Set 9 | wewak
# Processing Record 23 of Set 9 | raudeberg
# Processing Record 24 of Set 9 | kloulklubed
# Processing Record 25 of Set 9 | bonavista
# Processing Record 26 of Set 9 | hami
# Processing Record 27 of Set 9 | puerto quijarro
# Processing Record 28 of Set 9 | praia
# Processing Record 29 of Set 9 | maarianhamina
# Processing Record 30 of Set 9 | tyukhtet
# Processing Record 31 of Set 9 | mondovi
# Processing Record 32 of Set 9 | attawapiskat
# ........City not found. Skipping.......
# Processing Record 33 of Set 9 | boa vista
# Processing Record 34 of Set 9 | takaka
# Processing Record 35 of Set 9 | alta floresta
# Processing Record 36 of Set 9 | angoram
# Processing Record 37 of Set 9 | hope
# Processing Record 38 of Set 9 | sinnamary
# Processing Record 39 of Set 9 | maryville
# Processing Record 40 of Set 9 | ngaoundere
# Processing Record 41 of Set 9 | bangassou
# Processing Record 42 of Set 9 | terney
# Processing Record 43 of Set 9 | walvis bay
# Processing Record 44 of Set 9 | kavieng
# Processing Record 45 of Set 9 | alotau
# ........City not found. Skipping.......
# Processing Record 46 of Set 9 | houma
# Processing Record 47 of Set 9 | zarechnyy
# Processing Record 48 of Set 9 | biak
# Processing Record 49 of Set 9 | camacari
# Processing Record 50 of Set 9 | yei
# Processing Record 1 of Set 10 | muros
# Processing Record 2 of Set 10 | zhezkazgan
# Processing Record 3 of Set 10 | navlya
# Processing Record 4 of Set 10 | caronport
# Processing Record 5 of Set 10 | dudinka
# Processing Record 6 of Set 10 | ontario
# Processing Record 7 of Set 10 | chaa-khol
# ........City not found. Skipping.......
# Processing Record 8 of Set 10 | hargeysa
# Processing Record 9 of Set 10 | sayyan
# Processing Record 10 of Set 10 | kirkwood
# Processing Record 11 of Set 10 | qaqortoq
# Processing Record 12 of Set 10 | mutoko
# Processing Record 13 of Set 10 | betki
# ........City not found. Skipping.......
# Processing Record 14 of Set 10 | grand gaube
# Processing Record 15 of Set 10 | montrose
# Processing Record 16 of Set 10 | jelgava
# Processing Record 17 of Set 10 | nhulunbuy
# Processing Record 18 of Set 10 | lazaro cardenas
# Processing Record 19 of Set 10 | okahandja
# Processing Record 20 of Set 10 | diego de almagro
# Processing Record 21 of Set 10 | valley city
# Processing Record 22 of Set 10 | mandera
# Processing Record 23 of Set 10 | komsomolskiy
# Processing Record 24 of Set 10 | saldanha
# Processing Record 25 of Set 10 | itoman
# Processing Record 26 of Set 10 | sao jose da coroa grande
# Processing Record 27 of Set 10 | maua
# Processing Record 28 of Set 10 | doha
# Processing Record 29 of Set 10 | castro
# Processing Record 30 of Set 10 | eldikan
# ........City not found. Skipping.......
# Processing Record 31 of Set 10 | mildura
# Processing Record 32 of Set 10 | itarema
# Processing Record 33 of Set 10 | banda aceh
# Processing Record 34 of Set 10 | harlingen
# Processing Record 35 of Set 10 | yuli
# Processing Record 36 of Set 10 | narsaq
# Processing Record 37 of Set 10 | altay
# Processing Record 38 of Set 10 | pipar
# Processing Record 39 of Set 10 | superior
# Processing Record 40 of Set 10 | along
# Processing Record 41 of Set 10 | padang
# Processing Record 42 of Set 10 | nanortalik
# Processing Record 43 of Set 10 | gympie
# Processing Record 44 of Set 10 | gikongoro
# Processing Record 45 of Set 10 | hailar
# Processing Record 46 of Set 10 | miramar
# Processing Record 47 of Set 10 | karratha
# Processing Record 48 of Set 10 | beloha
# Processing Record 49 of Set 10 | yumen
# Processing Record 50 of Set 10 | lieksa
# Processing Record 1 of Set 11 | san rafael
# Processing Record 2 of Set 11 | yulara
# Processing Record 3 of Set 11 | stromness
# Processing Record 4 of Set 11 | capoterra
# Processing Record 5 of Set 11 | jizan
# Processing Record 6 of Set 11 | verkhneuralsk
# Processing Record 7 of Set 11 | havoysund
# Processing Record 8 of Set 11 | ballina
# Processing Record 9 of Set 11 | antalaha
# Processing Record 10 of Set 11 | koygorodok
# Processing Record 11 of Set 11 | henties bay
# Processing Record 12 of Set 11 | goderich
# Processing Record 13 of Set 11 | togur
# Processing Record 14 of Set 11 | sakakah
# Processing Record 15 of Set 11 | sokoni
# Processing Record 16 of Set 11 | sola
# Processing Record 17 of Set 11 | hasaki
# Processing Record 18 of Set 11 | sanger
# Processing Record 19 of Set 11 | poya
# Processing Record 20 of Set 11 | mangaratiba
# Processing Record 21 of Set 11 | japura
# Processing Record 22 of Set 11 | stepnogorsk
# Processing Record 23 of Set 11 | lumphat
# Processing Record 24 of Set 11 | arlit
# Processing Record 25 of Set 11 | vardo
# Processing Record 26 of Set 11 | saint anthony
# Processing Record 27 of Set 11 | nechi
# Processing Record 28 of Set 11 | te anau
# Processing Record 29 of Set 11 | nadym
# Processing Record 30 of Set 11 | korla
# Processing Record 31 of Set 11 | thinadhoo
# Processing Record 32 of Set 11 | manga
# Processing Record 33 of Set 11 | quang ngai
# Processing Record 34 of Set 11 | cochrane
# Processing Record 35 of Set 11 | urucui
# Processing Record 36 of Set 11 | pangnirtung
# Processing Record 37 of Set 11 | yar-sale
# Processing Record 38 of Set 11 | ouesso
# Processing Record 39 of Set 11 | baraboo
# Processing Record 40 of Set 11 | kosh-agach
# Processing Record 41 of Set 11 | coroico
# Processing Record 42 of Set 11 | worland
# Processing Record 43 of Set 11 | urucara
# Processing Record 44 of Set 11 | kota bahru
# Processing Record 45 of Set 11 | hamilton
# Processing Record 46 of Set 11 | nishihara
# Processing Record 47 of Set 11 | ibipeba
# Processing Record 48 of Set 11 | lompoc
# Processing Record 49 of Set 11 | allapalli
# Processing Record 50 of Set 11 | altos del rosario
# Processing Record 1 of Set 12 | caborca
# Processing Record 2 of Set 12 | keelung
# Processing Record 3 of Set 12 | champerico
# Processing Record 4 of Set 12 | santa leopoldina
# Processing Record 5 of Set 12 | san cristobal
# Processing Record 6 of Set 12 | bandarbeyla
# Processing Record 7 of Set 12 | sangmelima
# Processing Record 8 of Set 12 | gayny
# Processing Record 9 of Set 12 | gagra
# Processing Record 10 of Set 12 | ban dung
# Processing Record 11 of Set 12 | mariental
# Processing Record 12 of Set 12 | berekum
# Processing Record 13 of Set 12 | bonthe
# Processing Record 14 of Set 12 | sao joaquim
# Processing Record 15 of Set 12 | pitimbu
# Processing Record 16 of Set 12 | san andres
# Processing Record 17 of Set 12 | tynda
# Processing Record 18 of Set 12 | taksimo
# Processing Record 19 of Set 12 | salinopolis
# Processing Record 20 of Set 12 | yabassi
# Processing Record 21 of Set 12 | port hardy
# Processing Record 22 of Set 12 | farafangana
# Processing Record 23 of Set 12 | mtwara
# Processing Record 24 of Set 12 | ormiston
# Processing Record 25 of Set 12 | westport
# Processing Record 26 of Set 12 | kormilovka
# Processing Record 27 of Set 12 | lanzhou
# Processing Record 28 of Set 12 | bogorodskoye
# Processing Record 29 of Set 12 | kara-tyube
# Processing Record 30 of Set 12 | birao
# Processing Record 31 of Set 12 | mwingi
# Processing Record 32 of Set 12 | hambantota
# Processing Record 33 of Set 12 | wilmington
# Processing Record 34 of Set 12 | karaul
# ........City not found. Skipping.......
# Processing Record 35 of Set 12 | vagur
# Processing Record 36 of Set 12 | asosa
# Processing Record 37 of Set 12 | dawson creek
# Processing Record 38 of Set 12 | geraldton
# Processing Record 39 of Set 12 | toliary
# ........City not found. Skipping.......
# Processing Record 40 of Set 12 | bluefield
# Processing Record 41 of Set 12 | lavumisa
# Processing Record 42 of Set 12 | chicama
# Processing Record 43 of Set 12 | nantucket
# Processing Record 44 of Set 12 | tikrit
# Processing Record 45 of Set 12 | xining
# Processing Record 46 of Set 12 | pedernales
# Processing Record 47 of Set 12 | tromso
# Processing Record 48 of Set 12 | zhemchuzhnyy
# ........City not found. Skipping.......
# Processing Record 49 of Set 12 | gondanglegi
# Processing Record 50 of Set 12 | mucurici
# Processing Record 1 of Set 13 | kalmunai
# Processing Record 2 of Set 13 | emba
# Processing Record 3 of Set 13 | ludvika
# Processing Record 4 of Set 13 | masaka
# Processing Record 5 of Set 13 | acarau
# Processing Record 6 of Set 13 | muisne
# Processing Record 7 of Set 13 | tara
# Processing Record 8 of Set 13 | flinders
# Processing Record 9 of Set 13 | prince rupert
# Processing Record 10 of Set 13 | arman
# Processing Record 11 of Set 13 | dolinsk
# Processing Record 12 of Set 13 | ransang
# Processing Record 13 of Set 13 | vila velha
# Processing Record 14 of Set 13 | bambanglipuro
# Processing Record 15 of Set 13 | ayan
# Processing Record 16 of Set 13 | constantine
# Processing Record 17 of Set 13 | linxia
# Processing Record 18 of Set 13 | una
# Processing Record 19 of Set 13 | roebourne
# Processing Record 20 of Set 13 | tamale
# Processing Record 21 of Set 13 | aden
# Processing Record 22 of Set 13 | buraydah
# Processing Record 23 of Set 13 | nguiu
# ........City not found. Skipping.......
# Processing Record 24 of Set 13 | guajara
# Processing Record 25 of Set 13 | yaan
# Processing Record 26 of Set 13 | jiayuguan
# Processing Record 27 of Set 13 | tessalit
# Processing Record 28 of Set 13 | livny
# Processing Record 29 of Set 13 | soligalich
# Processing Record 30 of Set 13 | makakilo city
# Processing Record 31 of Set 13 | rolim de moura
# ........City not found. Skipping.......
# Processing Record 32 of Set 13 | abeche
# Processing Record 33 of Set 13 | rodrigues alves
# Processing Record 34 of Set 13 | bungahan
# Processing Record 35 of Set 13 | dubreka
# Processing Record 36 of Set 13 | hirara
# Processing Record 37 of Set 13 | yerbogachen
# Processing Record 38 of Set 13 | ratnagiri
# Processing Record 39 of Set 13 | talaya
# Processing Record 40 of Set 13 | bilma
# Processing Record 41 of Set 13 | yanaul
# Processing Record 42 of Set 13 | ambulu
# Processing Record 43 of Set 13 | muroto
# Processing Record 44 of Set 13 | kiama
# Processing Record 45 of Set 13 | laje
# Processing Record 46 of Set 13 | orange cove
# Processing Record 47 of Set 13 | rognan
# Processing Record 48 of Set 13 | taoudenni
# Processing Record 49 of Set 13 | takoradi
# Processing Record 50 of Set 13 | chapais
# Processing Record 1 of Set 14 | fevralsk
# ........City not found. Skipping.......
# Processing Record 2 of Set 14 | sangar
# Processing Record 3 of Set 14 | panaba
# Processing Record 4 of Set 14 | hecun
# Processing Record 5 of Set 14 | taburbah
# ........City not found. Skipping.......
# Processing Record 6 of Set 14 | aktash
# Processing Record 7 of Set 14 | mao
# Processing Record 8 of Set 14 | lekoni
# Processing Record 9 of Set 14 | teya
# Processing Record 10 of Set 14 | putyatino
# Processing Record 11 of Set 14 | taborfalva
# Processing Record 12 of Set 14 | bom jardim
# Processing Record 13 of Set 14 | swidwin
# Processing Record 14 of Set 14 | santa marta
# Processing Record 15 of Set 14 | chute-aux-outardes
# Processing Record 16 of Set 14 | marsa matruh
# Processing Record 17 of Set 14 | saint andrews
# Processing Record 18 of Set 14 | dali
# Processing Record 19 of Set 14 | yuzhno-yeniseyskiy
# ........City not found. Skipping.......
# Processing Record 20 of Set 14 | sept-iles
# Processing Record 21 of Set 14 | puerto leguizamo
# Processing Record 22 of Set 14 | malanje
# Processing Record 23 of Set 14 | wenchi
# Processing Record 24 of Set 14 | xifeng
# Processing Record 25 of Set 14 | honiara
# Processing Record 26 of Set 14 | berdigestyakh
# Processing Record 27 of Set 14 | lavrentiya
# Processing Record 28 of Set 14 | bereda
# Processing Record 29 of Set 14 | tonj
# Processing Record 30 of Set 14 | plouzane
# Processing Record 31 of Set 14 | mkushi
# Processing Record 32 of Set 14 | herat
# Processing Record 33 of Set 14 | matara
# Processing Record 34 of Set 14 | dryden
# Processing Record 35 of Set 14 | sholapur
# Processing Record 36 of Set 14 | san isidro
# Processing Record 37 of Set 14 | kinangan
# Processing Record 38 of Set 14 | ossora
# Processing Record 39 of Set 14 | mitchell
# Processing Record 40 of Set 14 | fort-shevchenko
# Processing Record 41 of Set 14 | ostrovnoy
# Processing Record 42 of Set 14 | khandyga
# Processing Record 43 of Set 14 | laiya
# Processing Record 44 of Set 14 | shibetsu
# Processing Record 45 of Set 14 | machinga
# Processing Record 46 of Set 14 | ushirombo
# Processing Record 47 of Set 14 | dunedin
# Processing Record 48 of Set 14 | polson
# Processing Record 49 of Set 14 | charleston
# Processing Record 50 of Set 14 | tonk
# Processing Record 1 of Set 15 | semey
# Processing Record 2 of Set 15 | bull savanna
# Processing Record 3 of Set 15 | nsanje
# Processing Record 4 of Set 15 | dhidhdhoo
# Processing Record 5 of Set 15 | middle island
# Processing Record 6 of Set 15 | falealupo
# ........City not found. Skipping.......
# Processing Record 7 of Set 15 | zima
# Processing Record 8 of Set 15 | alvaraes
# Processing Record 9 of Set 15 | dzhusaly
# ........City not found. Skipping.......
# Processing Record 10 of Set 15 | nouakchott
# Processing Record 11 of Set 15 | ternate
# Processing Record 12 of Set 15 | tamandare
# Processing Record 13 of Set 15 | matagami
# Processing Record 14 of Set 15 | maceio
# Processing Record 15 of Set 15 | kismayo
# Processing Record 16 of Set 15 | alekseyevskoye
# Processing Record 17 of Set 15 | abu dhabi
# Processing Record 18 of Set 15 | mareeba
# Processing Record 19 of Set 15 | yinchuan
# Processing Record 20 of Set 15 | russell
# Processing Record 21 of Set 15 | fort nelson
# Processing Record 22 of Set 15 | ulladulla
# Processing Record 23 of Set 15 | tongchuan
# Processing Record 24 of Set 15 | lubango
# Processing Record 25 of Set 15 | waiuku
# Processing Record 26 of Set 15 | point pedro
# Processing Record 27 of Set 15 | pilar
# Processing Record 28 of Set 15 | matay
# Processing Record 29 of Set 15 | ibaiti
# Processing Record 30 of Set 15 | aksha
# Processing Record 31 of Set 15 | patos de minas
# Processing Record 32 of Set 15 | hong gai
# Processing Record 33 of Set 15 | seguin
# Processing Record 34 of Set 15 | riyadh
# Processing Record 35 of Set 15 | manzil jamil
# ........City not found. Skipping.......
# Processing Record 36 of Set 15 | skjervoy
# Processing Record 37 of Set 15 | samarai
# Processing Record 38 of Set 15 | podporozhye
# Processing Record 39 of Set 15 | ca mau
# Processing Record 40 of Set 15 | rennes
# Processing Record 41 of Set 15 | jieshi
# Processing Record 42 of Set 15 | horodok
# Processing Record 43 of Set 15 | awjilah
# Processing Record 44 of Set 15 | fillmore
# Processing Record 45 of Set 15 | teguldet
# Processing Record 46 of Set 15 | rio grande
# Processing Record 47 of Set 15 | znamenskoye
# Processing Record 48 of Set 15 | trairi
# Processing Record 49 of Set 15 | los llanos de aridane
# Processing Record 50 of Set 15 | acapulco
# Processing Record 1 of Set 16 | tigil
# Processing Record 2 of Set 16 | bria
# Processing Record 3 of Set 16 | yenagoa
# Processing Record 4 of Set 16 | bagdarin
# Processing Record 5 of Set 16 | casma
# Processing Record 6 of Set 16 | dixon
# Processing Record 7 of Set 16 | igrim
# Processing Record 8 of Set 16 | sinazongwe
# Processing Record 9 of Set 16 | valdivia
# Processing Record 10 of Set 16 | okhotsk
# Processing Record 11 of Set 16 | olinda
# ..............Data Retrieval Complete...........

# %%
len(city_data)
# Out:
# 705

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#        City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Tasiilaq      GL  65.6145  -37.6368     32.16        99         100
# 1   Ushuaia      AR -54.8000  -68.3000     48.09        73         100
# 2    Avarua      CK -21.2078 -159.7750     69.85       100          40
# 3   Rikitea      PF -23.1203 -134.9692     73.31        73          98
# 4  San Jose      US  37.3394 -121.8950     64.69        67           1
# 5     Ancud      CL -41.8697  -73.8203     61.43        68          97
# 6    Boddam      GB  57.4667   -1.7833     52.18        89         100
# 7   Lazurne      UA  46.0840   32.5295     48.45        74          97
# 8  Thompson      CA  55.7435  -97.8558     21.27        88          73
# 9   Mataura      NZ -46.1927  168.8643     48.02        99          98
#
#    Wind Speed Current Description
# 0        3.85                snow
# 1        5.44          light rain
# 2        1.14    scattered clouds
# 3       15.28     overcast clouds
# 4        0.00                mist
# 5       13.91          light rain
# 6       25.43     overcast clouds
# 7       16.17     overcast clouds
# 8        5.84       broken clouds
# 9        2.35     overcast clouds

# %%
#Create output file
output_data_file = "WeatherPy_Database.csv"

# Export DataFrame into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
